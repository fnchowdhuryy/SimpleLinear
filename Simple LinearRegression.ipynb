# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=1/3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
regressor.predict([[10]])
# Out:
# array([117718.63200151])

# %%
y_pred=regressor.predict(xtest)

# %%
regressor.score(x,y)
# Out:
# 0.9540437184806171

# %%
df['y_pred']=regressor.predict(x)
df.head()
# Out:
#    YearsExperience   Salary        y_pred
# 0              1.1  39343.0  36211.193133
# 1              1.3  46205.0  38042.820973
# 2              1.5  37731.0  39874.448812
# 3              2.0  43525.0  44453.518412
# 4              2.2  39891.0  46285.146251

# %%
plt.scatter(xtrain,ytrain,color='red')
plt.plot(xtrain,regressor.predict(xtrain),color='blue')
plt.title('salary vs experience(training data )')
plt.xlabel('yrs of experiencd')
plt.ylabel('salary')
plt.show()

# %%
plt.scatter(xtest,ytest,color='black')
plt.plot(xtrain,regressor.predict(xtrain),color='green')
plt.title('salary vs experience(testing data )')
plt.xlabel('yrs of experiencd')
plt.ylabel('salary')
plt.show()
